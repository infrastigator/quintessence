# %% [markdown]
# For a given company number, the tool will grab data from Companies House and then attempt to score the company on a number of criteria. The higher the score, the more red flags and the greater the suggestion to investigate the company.
#
# Currently the following flags are evaluated:
#
# - person's name is fake / in bad reputation list / looks random
# - person's name is mentioned in the news
# - person's nationality is from a list of red flag countries
# - person's country of residence is from a list of red flag countries
# - person's age is problematic

# %% [markdown]
# ### KINGDOM OF SWEETS LTD

# %%
# !python main.py 11004735
# Out:
# {'links': {'self': '/company/11004735/persons-with-significant-control'}, 'active_count': 1, 'items_per_page': 25, 'items': [{'country_of_residence': 'England', 'etag': 'c6c04d72359cd8c9700bc17193edfe5d272a2781', 'notified_on': '2017-10-10', 'date_of_birth': {'year': 1981, 'month': 9}, 'links': {'self': '/company/11004735/persons-with-significant-control/individual/WFDGm9WCMXDcz4hkc92RPWayyWo'}, 'natures_of_control': ['ownership-of-shares-75-to-100-percent', 'voting-rights-75-to-100-percent', 'right-to-appoint-and-remove-directors'], 'nationality': 'British', 'name_elements': {'middle_name': 'James Bailey Earl', 'surname': 'Manders', 'forename': 'Chase', 'title': 'Mr'}, 'name': 'Mr Chase James Bailey Earl Manders', 'address': {'locality': 'Wallsend', 'premises': 'Burnard Accountants, 8 Bankside Building', 'country': 'United Kingdom', 'address_line_2': 'Station Road', 'postal_code': 'NE28 6HQ', 'region': 'Tyne & Wear', 'address_line_1': 'Segedunum Business Centre'}, 'kind': 'individual-person-with-significant-control'}], 'total_results': 1, 'ceased_count': 0, 'start_index': 0}
# {
#     "filing_history_status": "filing-history-available",
#     "items": [
#         {
#             "action_date": "2022-09-25",
#             "category": "confirmation-statement",
#             "date": "2022-09-25",
#             "description": "confirmation-statement-with-no-updates",
#             "description_values": {
#                 "made_up_date": "2022-09-25"
#             },
#             "links": {
#                 "self": "/company/11004735/filing-history/MzM1MjkxMjAxNWFkaXF6a2N4",
#                 "document_metadata": "https://frontend-doc-api.company-information.service.gov.uk/document/huvQJe6k1PYpXMGQjSVfmVqlwYKRyv1BwEOF95BnH58"
#             },
#             "type": "CS01",
#             "pages": 3,
#             "barcode": "XBD9KYBK",
#             "transaction_id": "MzM1MjkxMjAxNWFkaXF6a2N4"
#         },
#         {
#             "action_date": "2021-10-09",
#             "category": "confirmation-statement",
#             "date": "2021-11-14",
#             "description": "confirmation-statement-with-updates",
#             "description_values": {
#                 "made_up_date": "2021-10-09"
#             },
#             "links": {
#                 "self": "/company/11004735/filing-history/MzMyMDEyMDgxN2FkaXF6a2N4",
#                 "document_metadata": "https://frontend-doc-api.company-information.service.gov.uk/document/2j08yYdyV2Oszapc6brLz5IeT97o4LbgWDc4lez_CUY"
#             },
#             "type": "CS01",
#             "pages": 4,
#             "barcode": "XAH8U7F5",
#             "transaction_id": "MzMyMDEyMDgxN2FkaXF6a2N4"
#         },
#         {
#             "action_date": "2021-09-27",
#             "category": "capital",
#             "date": "2021-10-11",
#             "description": "capital-allotment-shares",
#             "description_values": {
#                 "date": "2021-09-27",
#                 "capital": [
#                     {
#                         "figure": "718",
#                         "currency": "GBP"
#                     }
#                 ]
#             },
#             "links": {
#                 "self": "/company/11004735/filing-history/MzMxNjIyNjAxNmFkaXF6a2N4",
#                 "document_metadata": "https://frontend-doc-api.company-information.service.gov.uk/document/ZFCeh9wBOCh1lchgNjlGhQfzZFn2VDrodCW8hxwoMzU"
#             },
#             "paper_filed": true,
#             "type": "SH01",
#             "pages": 4,
#             "barcode": "AAE6WDJN",
#             "transaction_id": "MzMxNjIyNjAxNmFkaXF6a2N4"
#         },
#         {
#             "category": "resolution",
#             "date": "2021-10-01",
#             "description": "resolution",
#             "description_values": {
#                 "description": "Resolutions"
#             },
#             "links": {
#                 "self": "/company/11004735/filing-history/QUFEUkw1SlZhZGlxemtjeA",
#                 "document_metadata": "https://frontend-doc-api.company-information.service.gov.uk/document/UMyF9kUJhzzutFuaQJRzOG1Pls91bK1OnUBbL0T7-rU"
#             },
#             "paper_filed": true,
#             "resolutions": [
#                 {
#                     "category": "capital",
#                     "description": "resolution-removal-pre-emption",
#                     "subcategory": "resolution",
#                     "type": "RES11"
#                 },
#                 {
#                     "category": "capital",
#                     "description": "resolution-securities",
#                     "subcategory": "resolution",
#                     "type": "RES10"
#                 }
#             ],
#             "type": "RESOLUTIONS",
#             "pages": 1,
#             "barcode": null,
#             "transaction_id": "QUFEUkw1SlZhZGlxemtjeA"
#         },
#         {
#             "action_date": "2020-12-31",
#             "category": "accounts",
#             "date": "2021-09-29",
#             "description": "accounts-with-accounts-type-dormant",
#             "description_values": {
#                 "made_up_date": "2020-12-31"
#             },
#             "links": {
#                 "self": "/company/11004735/filing-history/MzMxNTQzODY5MWFkaXF6a2N4",
#                 "document_metadata": "https://frontend-doc-api.company-information.service.gov.uk/document/jyfmVIPOmUBU9gUaPP62lBej7h071N3pXGDeCEnhDfo"
#             },
#             "type": "AA",
#             "pages": 6,
#             "barcode": "XAE1K8F6",
#             "transaction_id": "MzMxNTQzODY5MWFkaXF6a2N4"
#         },
#         {
#             "action_date": "2021-07-23",
#             "category": "address",
#             "date": "2021-07-23",
#             "description": "change-registered-office-address-company-with-date-old-address-new-address",
#             "description_values": {
#                 "change_date": "2021-07-23",
#                 "new_address": "3rd Floor 13 Charles Ii Street London Greater London SW1Y 4QU",
#                 "old_address": "Burnard Accountants, 8 Bankside Building Segedunum Business Centre Station Road Wallsend Tyne & Wear NE28 6HQ United Kingdom"
#             },
#             "links": {
#                 "self": "/company/11004735/filing-history/MzMwODU4OTI2OGFkaXF6a2N4",
#                 "document_metadata": "https://frontend-doc-api.company-information.service.gov.uk/document/UFh4WByZIMSTFRNSxUxpOgZd3_qipTb_P35F6GDacO8"
#             },
#             "type": "AD01",
#             "pages": 1,
#             "barcode": "XA9DEFBL",
#             "transaction_id": "MzMwODU4OTI2OGFkaXF6a2N4"
#         },
#         {
#             "action_date": "2021-06-17",
#             "category": "capital",
#             "date": "2021-07-16",
#             "description": "capital-allotment-shares",
#             "description_values": {
#                 "date": "2021-06-17",
#                 "capital": [
#                     {
#                         "figure": "517",
#                         "currency": "GBP"
#                     }
#                 ]
#             },
#             "links": {
#                 "self": "/company/11004735/filing-history/MzMwNzEzODIxMWFkaXF6a2N4",
#                 "document_metadata": "https://frontend-doc-api.company-information.service.gov.uk/document/8gR8zl7Tyr_ri3zuNFktvIVnI4QACOOdM2MDhuf5_ZI"
#             },
#             "paper_filed": true,
#             "type": "SH01",
#             "pages": 8,
#             "barcode": "AA7Z77KX",
#             "transaction_id": "MzMwNzEzODIxMWFkaXF6a2N4"
#         },
#         {
#             "category": "resolution",
#             "date": "2021-07-16",
#             "description": "resolution",
#             "description_values": {
#                 "description": "Resolutions"
#             },
#             "links": {
#                 "self": "/company/11004735/filing-history/QUE3Wjc3S1BhZGlxemtjeA",
#                 "document_metadata": "https://frontend-doc-api.company-information.service.gov.uk/document/tYWZ2ZfGCr0dm0SSffEM1TWy1ACoNk4CuDJWXSKTNvw"
#             },
#             "paper_filed": true,
#             "resolutions": [
#                 {
#                     "category": "capital",
#                     "description": "resolution-removal-pre-emption",
#                     "subcategory": "resolution",
#                     "type": "RES11"
#                 },
#                 {
#                     "category": "capital",
#                     "description": "resolution-securities",
#                     "subcategory": "resolution",
#                     "type": "RES10"
#                 }
#             ],
#             "type": "RESOLUTIONS",
#             "pages": 1,
#             "barcode": null,
#             "transaction_id": "QUE3Wjc3S1BhZGlxemtjeA"
#         },
#         {
#             "action_date": "2020-10-09",
#             "category": "confirmation-statement",
#             "date": "2020-12-09",
#             "description": "confirmation-statement-with-no-updates",
#             "description_values": {
#                 "made_up_date": "2020-10-09"
#             },
#             "links": {
#                 "self": "/company/11004735/filing-history/MzI4NTU0NjYyOWFkaXF6a2N4",
#                 "document_metadata": "https://frontend-doc-api.company-information.service.gov.uk/document/me85DwVYRmkpeBfh-kpgAy-L3HhxLiGMw6xfrTXyYrc"
#             },
#             "type": "CS01",
#             "pages": 3,
#             "barcode": "X9JIM6RL",
#             "transaction_id": "MzI4NTU0NjYyOWFkaXF6a2N4"
#         },
#         {
#             "action_date": "2020-12-31",
#             "category": "accounts",
#             "date": "2020-11-19",
#             "description": "change-account-reference-date-company-current-extended",
#             "description_values": {
#                 "new_date": "2020-12-31",
#                 "made_up_date": "2020-10-31"
#             },
#             "links": {
#                 "self": "/company/11004735/filing-history/MzI4Mzg4ODYxNGFkaXF6a2N4",
#                 "document_metadata": "https://frontend-doc-api.company-information.service.gov.uk/document/li8x1sIBMK_HvVpqveoZs6sDDgxuvtateTqAh4UpdRY"
#             },
#             "type": "AA01",
#             "pages": 1,
#             "barcode": "X9I6HV5U",
#             "transaction_id": "MzI4Mzg4ODYxNGFkaXF6a2N4"
#         },
#         {
#             "action_date": "2019-10-31",
#             "category": "accounts",
#             "date": "2020-03-05",
#             "description": "accounts-with-accounts-type-dormant",
#             "description_values": {
#                 "made_up_date": "2019-10-31"
#             },
#             "links": {
#                 "self": "/company/11004735/filing-history/MzI1OTA4MDkxN2FkaXF6a2N4",
#                 "document_metadata": "https://frontend-doc-api.company-information.service.gov.uk/document/ig1O0t8-uLLZGMzNK1sA56mAUeH2xEKSZhx_cbL8CNo"
#             },
#             "type": "AA",
#             "pages": 9,
#             "barcode": "X907D6E8",
#             "transaction_id": "MzI1OTA4MDkxN2FkaXF6a2N4"
#         },
#         {
#             "category": "confirmation-statement",
#             "date": "2019-10-24",
#             "type": "CS01",
#             "links": {
#                 "self": "/company/11004735/filing-history/MzI0NzU5Nzc5NGFkaXF6a2N4",
#                 "document_metadata": "https://frontend-doc-api.company-information.service.gov.uk/document/VDglX5HJTOh3EF-Jq5SSqaxqd6yGXY-eQ22_pjPrpMo"
#             },
#             "description_values": {
#                 "made_up_date": "2019-10-09"
#             },
#             "description": "confirmation-statement-with-no-updates",
#             "action_date": "2019-10-09",
#             "pages": 3,
#             "barcode": "X8GS53UR",
#             "transaction_id": "MzI0NzU5Nzc5NGFkaXF6a2N4"
#         },
#         {
#             "category": "accounts",
#             "type": "AA",
#             "description": "accounts-with-accounts-type-dormant",
#             "action_date": "2018-10-31",
#             "description_values": {
#                 "made_up_date": "2018-10-31"
#             },
#             "links": {
#                 "self": "/company/11004735/filing-history/MzIzODc4MzY1MGFkaXF6a2N4",
#                 "document_metadata": "https://frontend-doc-api.company-information.service.gov.uk/document/wGGWUStDq_U0UyWtjU3bLePx4IT5wsMde6s1uw7bhoc"
#             },
#             "date": "2019-07-08",
#             "pages": 9,
#             "barcode": "X89A2XYZ",
#             "transaction_id": "MzIzODc4MzY1MGFkaXF6a2N4"
#         },
#         {
#             "type": "CS01",
#             "links": {
#                 "self": "/company/11004735/filing-history/MzIyNjUzMTYyOWFkaXF6a2N4",
#                 "document_metadata": "https://frontend-doc-api.company-information.service.gov.uk/document/aLX-V5pMnN88Ch1LAdMY58gdn-otqdy_-wf6dOPm8r4"
#             },
#             "description_values": {
#                 "made_up_date": "2018-10-09"
#             },
#             "description": "confirmation-statement-with-no-updates",
#             "action_date": "2018-10-09",
#             "date": "2019-02-08",
#             "category": "confirmation-statement",
#             "pages": 3,
#             "barcode": "X7YTWPE9",
#             "transaction_id": "MzIyNjUzMTYyOWFkaXF6a2N4"
#         },
#         {
#             "category": "gazette",
#             "description": "gazette-filings-brought-up-to-date",
#             "date": "2019-02-02",
#             "links": {
#                 "self": "/company/11004735/filing-history/MzIyNjA0MjcwMWFkaXF6a2N4",
#                 "document_metadata": "https://frontend-doc-api.company-information.service.gov.uk/document/GqRJC1GFKkactn9l6xOL7PydI1lz2Z4DQLoLIN0Jiwk"
#             },
#             "paper_filed": true,
#             "type": "DISS40",
#             "pages": 1,
#             "barcode": null,
#             "transaction_id": "MzIyNjA0MjcwMWFkaXF6a2N4"
#         },
#         {
#             "date": "2019-01-08",
#             "description": "gazette-notice-compulsory",
#             "category": "gazette",
#             "type": "GAZ1",
#             "paper_filed": true,
#             "links": {
#                 "self": "/company/11004735/filing-history/MzIyMjU4NDIxMGFkaXF6a2N4",
#                 "document_metadata": "https://frontend-doc-api.company-information.service.gov.uk/document/1nQ3RIp9u_noW6olSs4uveYZXMMs9Bqc0nDU6T3vx6s"
#             },
#             "pages": 1,
#             "barcode": null,
#             "transaction_id": "MzIyMjU4NDIxMGFkaXF6a2N4"
#         },
#         {
#             "type": "NEWINC",
#             "links": {
#                 "self": "/company/11004735/filing-history/MzE4NzMyNzc5MGFkaXF6a2N4",
#                 "document_metadata": "https://frontend-doc-api.company-information.service.gov.uk/document/kfNa_RUeZ6VGo6RwLkHIBjXaj7_fLsbVGc5GDC2Guus"
#             },
#             "description": "incorporation-company",
#             "date": "2017-10-10",
#             "category": "incorporation",
#             "associated_filings": [
#                 {
#                     "action_date": 1507593600000,
#                     "category": "capital",
#                     "date": "2017-10-10",
#                     "description": "statement-of-capital",
#                     "description_values": {
#                         "capital": [
#                             {
#                                 "currency": "GBP",
#                                 "figure": "100"
#                             }
#                         ],
#                         "date": "2017-10-10"
#                     },
#                     "type": "SH01"
#                 },
#                 {
#                     "category": "incorporation",
#                     "date": "2017-10-10",
#                     "description": "model-articles-adopted",
#                     "type": "MODEL ARTICLES"
#                 }
#             ],
#             "pages": 29,
#             "barcode": "X6GNVU54",
#             "transaction_id": "MzE4NzMyNzc5MGFkaXF6a2N4"
#         }
#     ],
#     "start_index": 0,
#     "total_count": 17,
#     "items_per_page": 25
# }
# KINGDOM OF SWEETS LTD
#
#
# "Chase Manders" "KINGDOM OF SWEETS"
# ['Company linked to Oxford Street candy store operator shut down over unpaid tax', 'Taxing times for Kingdom of Sweets', 'The American candy shop scandal: how sweets led to decay on Oxford Street', 'EXCLUSIVE: Huge probe is launched into American candy stores', 'The hell of London’s ‘American’ candy stores', 'Why is central London suddenly full of American sweetshops?', 'Brokers remain bullish as takeover speculation lifts Sainsbury']
# England
# - MANDERS, Chase James Bailey Earl: 20.0 - (Red flags: news mentions of the individual)
# Officers weighted-average score: 20.0
#
#
# "Chase Manders" "KINGDOM OF SWEETS"
# ['Company linked to Oxford Street candy store operator shut down over unpaid tax', 'Taxing times for Kingdom of Sweets', 'The American candy shop scandal: how sweets led to decay on Oxford Street', 'EXCLUSIVE: Huge probe is launched into American candy stores', 'The hell of London’s ‘American’ candy stores', 'Why is central London suddenly full of American sweetshops?', 'Brokers remain bullish as takeover speculation lifts Sainsbury']
# England
# - Mr Chase James Bailey Earl Manders: 20.0 - (Red flags: news mentions of the individual)
# PSCs weighted-average score: 20.0
#
#
# {
#     "officers": 20.0,
#     "pscs": 20.0
# }

# %% [markdown]
# We can see officers and pscs are comprised of the same single person with a red flag raised due to mention of the officer and company in the news. A quick scan of the news articles suggests the company is embroiled in unpaid taxes and scandal.

# %% [markdown]
# ### WEIGHT A MINUTE LTD

# %%
# !python main.py 08881386
# Out:
# {'items': [{'notified_on': '2017-01-01', 'links': {'self': '/company/08881386/persons-with-significant-control/individual/2rlNWhEeiwwOVpoURWC0PG3_k0c'}, 'address': {'region': 'Middlesex', 'address_line_1': 'Swinfield Close', 'locality': 'Feltham', 'premises': '9', 'postal_code': 'TW13 6YN'}, 'name': 'Mr Anthony Hardley', 'kind': 'individual-person-with-significant-control', 'etag': '056a671aa72ba87ae0cd78a044f33c3bca17565f', 'nationality': 'Jamaican', 'natures_of_control': ['ownership-of-shares-75-to-100-percent'], 'name_elements': {'surname': 'Hardley', 'title': 'Mr', 'forename': 'Anthony'}, 'date_of_birth': {'month': 1, 'year': 1977}, 'country_of_residence': 'United Kingdom'}], 'ceased_count': 0, 'links': {'self': '/company/08881386/persons-with-significant-control'}, 'total_results': 1, 'start_index': 0, 'items_per_page': 25, 'active_count': 1}
# {
#     "filing_history_status": "filing-history-available",
#     "items_per_page": 25,
#     "total_count": 12,
#     "items": [
#         {
#             "category": "gazette",
#             "date": "2018-02-13",
#             "links": {
#                 "self": "/company/08881386/filing-history/MzE5NzA1MTM2OGFkaXF6a2N4",
#                 "document_metadata": "https://frontend-doc-api.company-information.service.gov.uk/document/4vwHAe-O3Uz1uMsmdcsWPBfd7lLZJcczFHlxC-1HWeQ"
#             },
#             "paper_filed": true,
#             "type": "GAZ2(A)",
#             "description": "gazette-dissolved-voluntary",
#             "pages": 1,
#             "barcode": null,
#             "transaction_id": "MzE5NzA1MTM2OGFkaXF6a2N4"
#         },
#         {
#             "description": "gazette-notice-voluntary",
#             "date": "2017-11-28",
#             "paper_filed": true,
#             "category": "gazette",
#             "type": "GAZ1(A)",
#             "links": {
#                 "self": "/company/08881386/filing-history/MzE5MDM1MjU5NmFkaXF6a2N4",
#                 "document_metadata": "https://frontend-doc-api.company-information.service.gov.uk/document/tjwj3ut_gKK-eJG13QkJXADWW3kLDTv33u1f_FQmw7w"
#             },
#             "pages": 1,
#             "barcode": null,
#             "transaction_id": "MzE5MDM1MjU5NmFkaXF6a2N4"
#         },
#         {
#             "type": "DS01",
#             "links": {
#                 "self": "/company/08881386/filing-history/MzE5MDE1MDY4N2FkaXF6a2N4",
#                 "document_metadata": "https://frontend-doc-api.company-information.service.gov.uk/document/Uze7oyrcdtLDnHaDs3aYOjKNesv89UhHuxh6lP-2vxA"
#             },
#             "description": "dissolution-application-strike-off-company",
#             "date": "2017-11-16",
#             "paper_filed": true,
#             "category": "dissolution",
#             "pages": 3,
#             "barcode": "A6IXUD7F",
#             "transaction_id": "MzE5MDE1MDY4N2FkaXF6a2N4"
#         },
#         {
#             "links": {
#                 "self": "/company/08881386/filing-history/MzE4NTU0MTU1NGFkaXF6a2N4",
#                 "document_metadata": "https://frontend-doc-api.company-information.service.gov.uk/document/y2gs53tGF8Na0kzIqzUo2D_NAuUshOE1_XRS_CnagOo"
#             },
#             "description": "accounts-with-accounts-type-dormant",
#             "category": "accounts",
#             "date": "2017-09-18",
#             "action_date": "2016-11-07",
#             "description_values": {
#                 "made_up_date": "2016-11-07"
#             },
#             "type": "AA",
#             "pages": 2,
#             "barcode": "X6F89VBU",
#             "transaction_id": "MzE4NTU0MTU1NGFkaXF6a2N4"
#         },
#         {
#             "action_date": "2017-02-07",
#             "type": "CS01",
#             "date": "2017-04-13",
#             "description": "confirmation-statement-with-updates",
#             "links": {
#                 "self": "/company/08881386/filing-history/MzE3MzQ1Mzc0NmFkaXF6a2N4",
#                 "document_metadata": "https://frontend-doc-api.company-information.service.gov.uk/document/JLHo8eU44KMenVFfDiSSTd99pmjOUysrXlTRyv2vm0A"
#             },
#             "description_values": {
#                 "made_up_date": "2017-02-07"
#             },
#             "category": "confirmation-statement",
#             "pages": 5,
#             "barcode": "X648BBOB",
#             "transaction_id": "MzE3MzQ1Mzc0NmFkaXF6a2N4"
#         },
#         {
#             "category": "accounts",
#             "description_values": {
#                 "made_up_date": "2015-11-07"
#             },
#             "action_date": "2015-11-07",
#             "description": "accounts-with-accounts-type-dormant",
#             "links": {
#                 "self": "/company/08881386/filing-history/MzE1ODAwMzEzMmFkaXF6a2N4",
#                 "document_metadata": "https://frontend-doc-api.company-information.service.gov.uk/document/VclHgiFtt3DGk_q3DNAORJjkaY5eDFW9dnY1ifQ_VZM"
#             },
#             "date": "2016-09-23",
#             "type": "AA",
#             "pages": 2,
#             "barcode": "X5G3DY28",
#             "transaction_id": "MzE1ODAwMzEzMmFkaXF6a2N4"
#         },
#         {
#             "action_date": "2016-02-07",
#             "links": {
#                 "self": "/company/08881386/filing-history/MzE0NDgyNjkwM2FkaXF6a2N4",
#                 "document_metadata": "https://frontend-doc-api.company-information.service.gov.uk/document/PnnhXSYPSUSC7K3HG1mEGJK0Aqo5ywcJEp4bslvraIU"
#             },
#             "type": "AR01",
#             "description_values": {
#                 "made_up_date": "2016-02-07"
#             },
#             "date": "2016-03-24",
#             "category": "annual-return",
#             "description": "annual-return-company-with-made-up-date-full-list-shareholders",
#             "associated_filings": [
#                 {
#                     "action_date": 1458777600000,
#                     "category": "capital",
#                     "date": "2016-03-24",
#                     "description": "statement-of-capital",
#                     "description_values": {
#                         "capital": [
#                             {
#                                 "currency": "GBP",
#                                 "figure": "100"
#                             }
#                         ],
#                         "date": "2016-03-24"
#                     },
#                     "type": "SH01"
#                 }
#             ],
#             "pages": 3,
#             "barcode": "X53FU87M",
#             "transaction_id": "MzE0NDgyNjkwM2FkaXF6a2N4"
#         },
#         {
#             "description_values": {
#                 "made_up_date": "2015-02-28"
#             },
#             "type": "AA",
#             "date": "2015-11-04",
#             "description": "accounts-with-accounts-type-dormant",
#             "action_date": "2015-02-28",
#             "links": {
#                 "self": "/company/08881386/filing-history/MzEzNDUwMTIwMmFkaXF6a2N4",
#                 "document_metadata": "https://frontend-doc-api.company-information.service.gov.uk/document/8M4QeVZzNhJrQO15cSjggyyXHER0lg_pEVI205wftug"
#             },
#             "category": "accounts",
#             "pages": 2,
#             "barcode": "X4JFGWIY",
#             "transaction_id": "MzEzNDUwMTIwMmFkaXF6a2N4"
#         },
#         {
#             "description": "change-account-reference-date-company-current-shortened",
#             "action_date": "2015-11-07",
#             "category": "accounts",
#             "links": {
#                 "self": "/company/08881386/filing-history/MzEzNDM5OTg3NGFkaXF6a2N4",
#                 "document_metadata": "https://frontend-doc-api.company-information.service.gov.uk/document/i8li0xDcBRNcEyD8M6gfHNE3stIXxeYH3sNiDqaALG4"
#             },
#             "type": "AA01",
#             "description_values": {
#                 "new_date": "2015-11-07",
#                 "made_up_date": "2016-02-28"
#             },
#             "date": "2015-11-04",
#             "pages": 1,
#             "barcode": "X4JFBN0H",
#             "transaction_id": "MzEzNDM5OTg3NGFkaXF6a2N4"
#         },
#         {
#             "associated_filings": [
#                 {
#                     "action_date": 1426809600000,
#                     "category": "capital",
#                     "date": "2015-03-20",
#                     "description": "statement-of-capital",
#                     "description_values": {
#                         "capital": [
#                             {
#                                 "currency": "GBP",
#                                 "figure": "100"
#                             }
#                         ],
#                         "date": "2015-03-20"
#                     },
#                     "type": "SH01"
#                 }
#             ],
#             "category": "annual-return",
#             "type": "AR01",
#             "date": "2015-03-20",
#             "description": "annual-return-company-with-made-up-date-full-list-shareholders",
#             "action_date": "2015-02-07",
#             "description_values": {
#                 "made_up_date": "2015-02-07"
#             },
#             "links": {
#                 "document_metadata": "https://frontend-doc-api.company-information.service.gov.uk/document/mQ1CXyDQi5GRIQKaW_Nhw_Msk2PU8bFRZa4tlEmf_Dk",
#                 "self": "/company/08881386/filing-history/MzExOTU4NjEzNGFkaXF6a2N4"
#             },
#             "pages": 3,
#             "barcode": "X43KMFXV",
#             "transaction_id": "MzExOTU4NjEzNGFkaXF6a2N4"
#         },
#         {
#             "type": "TM01",
#             "description": "termination-director-company-with-name-termination-date",
#             "subcategory": "termination",
#             "action_date": "2015-02-02",
#             "category": "officers",
#             "description_values": {
#                 "termination_date": "2015-02-02",
#                 "officer_name": "Jesus Christ"
#             },
#             "date": "2015-03-06",
#             "pages": 1,
#             "links": {
#                 "document_metadata": "https://frontend-doc-api.company-information.service.gov.uk/document/QOhwPt4AI_SFHvBpt_LfRPhIdHyNU82Eug_pqeT0Fsc",
#                 "self": "/company/08881386/filing-history/MzExODY4MDk2NGFkaXF6a2N4"
#             },
#             "barcode": "X42MOEBK",
#             "transaction_id": "MzExODY4MDk2NGFkaXF6a2N4"
#         },
#         {
#             "associated_filings": [
#                 {
#                     "action_date": 1391731200000,
#                     "category": "capital",
#                     "data": {},
#                     "date": "2014-02-07",
#                     "description": "statement-of-capital",
#                     "description_values": {
#                         "capital": [
#                             {
#                                 "currency": "GBP",
#                                 "figure": "100"
#                             }
#                         ],
#                         "date": "2014-02-07"
#                     },
#                     "type": "SH01"
#                 },
#                 {
#                     "type": "MODEL ARTICLES",
#                     "date": "2014-02-07",
#                     "description": "model-articles-adopted",
#                     "category": "incorporation"
#                 }
#             ],
#             "type": "NEWINC",
#             "date": "2014-02-07",
#             "description": "incorporation-company",
#             "category": "incorporation",
#             "links": {
#                 "document_metadata": "https://frontend-doc-api.company-information.service.gov.uk/document/JQMCDPWE1sA4dAnAiwFG3kJXo11ahoqtAy1CMs-_pYk",
#                 "self": "/company/08881386/filing-history/MzA5NDAzODk2NWFkaXF6a2N4"
#             },
#             "pages": 7,
#             "paper_filed": true,
#             "barcode": "X315765U",
#             "transaction_id": "MzA5NDAzODk2NWFkaXF6a2N4"
#         }
#     ],
#     "start_index": 0
# }
# WEIGHT A MINUTE LTD
#
#
# "Anthony Hardley" "WEIGHT A MINUTE"
# []
# United Kingdom
# - HARDLEY, Anthony: 0
# "Jesus Christ" "WEIGHT A MINUTE"
# []
# Heaven
# - CHRIST, Jesus, Holy: 20.0 - (Red flags: individual names found in list of fake / generic names)
# Officers weighted-average score: 10.0
#
#
# "Anthony Hardley" "WEIGHT A MINUTE"
# []
# United Kingdom
# - Mr Anthony Hardley: 0
# PSCs weighted-average score: 0.0
#
#
# {
#     "officers": 10.0,
#     "pscs": 0.0
# }

# %% [markdown]
# Weight A Minute is blessed to have a an officer with a God complex.

# %% [markdown]
# ### PIZZAEXPRESS GROUP HOLDINGS LIMITED

# %%
# !python main.py 09115780

# %% [markdown]
# Many of Pizza Express' officers are from countries outside the UK.

# %% [markdown]
# ### RIGHT TIME RECRUITMENT LIMITED

# %%
# !python main.py 10370306

# %% [markdown]
# One of the famous officers from Right Time Recruitment was flagged for being above the age of 70.

# %% [markdown]
# Longer term we intend to implement many other flags and allow users to integrate their own easily. Some other flags in the pipeline are:

# %% [markdown]
# - are there any pscs?
# - does the company have a weird sic code?
# - is the company compliant in its reporting frequency?
# - is the company dormant currently?
# - has the company been dormant in previous years?
# - does the company have a fake or non-existant address?
# - does the registered address contain a high proportion of short lived, dissolved or fraudulent businesses?
# - does the officer have a large number of mandates?
# - does the officers companies frequently dissolve or lie dormant?
# - does a filing have inconsistencies?
# - do filings demonstrate losses?
